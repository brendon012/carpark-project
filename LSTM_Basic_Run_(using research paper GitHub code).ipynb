# %%
import torch
#!conda install -c peterjc123 pytorch
print(torch.__version__)
# !pip install torchnet
# !pip install torchtext

# %%
# !git clone https://github.com/nyu-mll/acceptability-judgments.git

# %%
# %cd acceptability-judgments

# %%
# !pip3 install -r requirements.txt

# %%
# !python setup.py develop

# %% [markdown]
# upload vocab.tsv into acceptability judgements folder
#
# upload and replace with edited trainer.py file under modules (edit is for line 243, tensor item())
#
# need to change filenames under acceptability_corpus/tokenized
#
# from to in_domain_train.tsv to train.tsv
#
# from in_domain_dev to dev.tsv
#
# from out_domain_dev to test.tsv

# %%
# !python acceptability/run.py -g -d acceptability_corpus/tokenized
# Out:
# Namespace(data='acceptability_corpus/tokenized', embedding='glove.840B.300d', should_not_preprocess_data=False, should_not_lowercase=False, preprocess_tokenizer='space', vocab_file='./vocab_100k.tsv', output_dir=None, glove=False, embedding_size=300, embedding_path=None, train_embeddings=False, imbalance=True, logs_dir='./logs', should_not_log=False, data_type='discriminator', model='lstm_pooling_classifier', save_loc='./save', gpu=True, crop_pad_length=30, seed=1111, buffer_size=1, stages_per_epoch=2, prints_per_stage=1, patience=20, epochs=10, batch_size=32, by_source=False, max_pool=False, hidden_size=300, num_layers=1, learning_rate=0.0005, dropout=0.5, encoding_size=100, encoder_num_layers=1, lm_path=None, encoder_path=None, encoding_type='lstm_pooling_classifier', evaluate_train=False, train_evaluate_interval=10, experiment_name='experiment_lstm_pooling_classifier_h_300_l_1_lr_0.0005_e_300_do_0.5', resume_file=None, resume=False)
# ...
